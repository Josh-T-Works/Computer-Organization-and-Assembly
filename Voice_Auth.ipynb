# %%
for i in range(15):
  print("Hi")
# Out:
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi

# %%
print("WHATTTTT NO WAY")
# Out:
# WHATTTTT

# %%
print("YOOOOO")
# Out:
# YOOOOO

# %%
print("BEGONE")
# Out:
# BEGONE
